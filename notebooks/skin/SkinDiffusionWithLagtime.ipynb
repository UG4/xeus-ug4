-- %% [markdown]
-- # Drug Transport across a Virtual Skin Membrane:  Extended version
-- [Previous Version](SkinDiffusion.ipybnd)

-- %% [markdown]
-- ## 1. Setup
--
-- ### Initialize UG4 (for 2D and standard algebra)

-- %%
InitUG(2, AlgebraType("CPU", 1));
ug_load_script("ug_util.lua")
ug_load_script("util/refinement_util.lua")
-- Out:
-- * Initializing: paths... done, bridge... done, plugins... fail                 *

-- %% [markdown]
-- ### Create Domain

-- %%
requiredSubsets = {"LIP", "COR", "BOTTOM_SC", "TOP_SC"}
gridName = "skin2d-aniso.ugx"
numRefs = 2

-- %%
dom = util.CreateDomain(gridName, numRefs, requiredSubsets)
-- Out:
-- Loading Domain skin2d-aniso.ugx ... done.
-- Performing integrity check on domain ... done.
-- Refining(2): 1 2 done.

-- %% [markdown]
-- ### Create Approximation space

-- %%
approxSpaceDesc = { fct = "u", type = "Lagrange", order = 1 }

-- %%
approxSpace = ApproximationSpace(dom)
approxSpace:add_fct(approxSpaceDesc.fct, approxSpaceDesc.type, approxSpaceDesc.order)
approxSpace:init_levels()
approxSpace:init_top_surface()
print("Approximation space:")
approxSpace:print_statistic()
-- Out:
-- Approximation space:
-- | ----------------------------------------------------------------------------------------- |
-- |  Number of DoFs (All Procs)                                                               |
-- |  Algebra: Block 1 (divide by 1 for #Index)                                                |
-- |                                                                                           |
-- |    GridLevel   |       Domain |       0: LIP |       1: COR | 2: BOTTOM_SC |    3: TOP_SC |
-- | ----------------------------------------------------------------------------------------- |
-- | (lev,    0)    |          680 |           32 |          608 |           20 |           20 |
-- | (lev,    1)    |         2613 |          783 |         1752 |           39 |           39 |
-- | (lev,    2)    |        10241 |         4367 |         5720 |           77 |           77 |
-- | (lev,    0, g) |          680 |           32 |          608 |           20 |           20 |
-- | (lev,    1, g) |         2613 |          783 |         1752 |           39 |           39 |
-- | (lev,    2, g) |        10241 |         4367 |         5720 |           77 |           77 |
-- | (surf, top)    |        10241 |         4367 |         5720 |           77 |           77 |
-- | ----------------------------------------------------------------------------------------- |
-- | For Legend and Options: print_statistic("legend").                                        |
-- | ----------------------------------------------------------------------------------------- |

-- %% [markdown]
-- ### Create a convection-diffusion-equation
-- Define model parameter

-- %%
K={
    ["LIP"] = 1.0, ["COR"] = 1.0,
}

D={
     ["LIP"] = 1, ["COR"] = 1.0, 
}

-- %%
elemDisc ={}

elemDisc["COR"] = ConvectionDiffusion("u", "COR", "fv1")
elemDisc["COR"]:set_diffusion(K["COR"]*D["COR"])
elemDisc["COR"]:set_mass_scale(K["COR"])

elemDisc["LIP"] = ConvectionDiffusion("u", "LIP", "fv1")
elemDisc["LIP"]:set_diffusion(K["LIP"]*D["LIP"])
elemDisc["LIP"]:set_mass_scale(K["LIP"])

-- %%
dirichletBnd = DirichletBoundary()
dirichletBnd:add(1.0, "u", "TOP_SC")
dirichletBnd:add(0.0, "u", "BOTTOM_SC")

-- %%
domainDisc = DomainDiscretization(approxSpace)
domainDisc:add(elemDisc["LIP"])
domainDisc:add(elemDisc["COR"])
domainDisc:add(dirichletBnd)

-- %% [markdown]
-- ## 2. Steady state problem
-- Flux is computed from steady state. Since configuration of a multigrid solver is somewhat tricky, we use an LU decomposition here:

-- %%
A = AssembledLinearOperator(domainDisc)
u = GridFunction(approxSpace)
b = GridFunction(approxSpace)
u:set(0.0)


domainDisc:assemble_linear(A, b)
domainDisc:adjust_solution(u)

myLinearSolver =LU()
myLinearSolver:init(A, u)
myLinearSolver:apply(u, b)

-- %% [markdown]
-- Compute $J_\infty=J(t=\infty)$ for
-- $$ J(t)=\frac{1}{|\Gamma|}\int_\Gamma (-KD \nabla u(t,x)) \cdot \vec n dA$$

-- %%
area=Integral(1.0, u, "BOTTOM_SC")
print("Surface area [um^2]:")
print(area)

surfaceFlux = {}
surfaceFlux["BOT"] = K["LIP"]*D["LIP"]*IntegrateNormalGradientOnManifold(u, "u", "BOTTOM_SC", "LIP")
surfaceFlux["TOP"] = K["LIP"]*D["LIP"]*IntegrateNormalGradientOnManifold(u, "u", "TOP_SC", "LIP")
print("Surface fluxes [kg/s]:")
print(surfaceFlux["TOP"])
print(surfaceFlux["BOT"])

print("Normalized Fluxes [kg / (mu^2 * s)]:")
print(surfaceFlux["TOP"]/area)
print(surfaceFlux["BOT"]/area)

Jref = 0.05681818181818

print("Non Fluxes [kg / (mu^2 * s)]:")
print(surfaceFlux["TOP"]/area)
print(surfaceFlux["BOT"]/area)
-- Out:
-- Surface area [um^2]:
-- 30.1
-- Surface fluxes [kg/s]:
-- -1.7102272727266
-- 1.7102272727272
-- Normalized Fluxes [kg / (mu^2 * s)]:
-- -0.05681818181816
-- 0.05681818181818

-- %% [markdown]
-- ## 3. Transient problem

-- %% [markdown]
-- After each time-step, we execute a a callback function `MyPostProcess`. In this function, print the solution and compute
-- $$
-- m(t_k):= \int_0^{t_k} J(s) \, ds \approx \sum_{i=1}^k(t_{i}- t_{i-1}) \frac{J(t_{i-1}) +J(t_i)}{2}
-- $$
-- using the trapeziod rule. Moreover, we also compute the lag time $\tau$ from $m(t_k) = J_\infty(t_k - \tau)$.

-- %%
-- auxiliary variables
-- for output 
out=VTKOutput()

-- for book-keeping
tOld = 0.0
jOld = 0.0
mOld = 0.0


function MyPostProcess(u, step, time)
  
  -- 1) Print solution to file.
  out:print("vtk/SkinDiffusionWithLagtime", u, step, time)
  
  -- 2) Compute fluxes.
  local gradFlux={}
  gradFlux["BOT"] = IntegrateNormalGradientOnManifold(u, "u", "BOTTOM_SC", "LIP")
  gradFlux["TOP"] = IntegrateNormalGradientOnManifold(u, "u", "TOP_SC", "LIP")
  
  local jTOP = K["LIP"]*D["LIP"]*gradFlux["TOP"]
  local jBOT = K["LIP"]*D["LIP"]*gradFlux["BOT"]
  print ("flux_top (\t"..time.."\t)=\t"..jTOP)
  print ("flux_bot (\t"..time.."\t)=\t"..jBOT)
  
  -- 3) Compute mass.
  local dt = time - tOld
  local mass = mOld + (time - tOld)*(jBOT + jOld)/2.0
  print ("mass_bot (\t"..time.."\t)=\t"..mass)
  
  -- 4) Compute lag time.
  print ("tlag=".. time - mass/jBOT )
  
  -- 5) Updates
  tOld = time
  jOld = jBOT
  mOld = mass

end

-- %% [markdown]
-- ### Solve transient problem
-- For the purpose of illustration, we solve using `SolveNonlinearTimeProblem`:
--
--  * First, we create a non-linear solver:

-- %%
local solverDesc = {

    type = "newton",
    linSolver = myLinearSolver,
}

nlsolver = util.solver.CreateSolver(solverDesc)

-- %% [markdown]
-- * Set initial value

-- %%
u:set(0.0)

-- %% [markdown]
-- * Execute time stepping loop w/ fixed time-step

-- %%
local startTime = 0.0
local endTime = 5000.0
local dt=25.0
local dtMin=2.5
util.SolveNonlinearTimeProblem(u, domainDisc, nlsolver, MyPostProcess, "vtk/skin",
                            "ImplEuler", 1, startTime, endTime, dt, dtMin);
-- Out:
-- SolveNonlinearTimeProblem, Newton Solver setup:
-- NewtonSolver
--  LinearSolver:
--  | LU Decomposition: Direct Solver for Linear Equation Systems.
--  |  Minimum Entries for Sparse LU: 4000
--  ConvergenceCheck: StdConvCheck( max steps = 100, min defect = 1e-12, relative reduction = 1e-06)
--  LineSearch:  not set.
--
-- >> Writing start values
-- flux_top (	0	)=	0
-- flux_bot (	0	)=	0
-- mass_bot (	0	)=	0
-- tlag=nan
-- ++++++ TIMESTEP 1 BEGIN (current time: 0) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    7.421977e+03      -------
--    #    1:    3.611000e-12    4.865281e-16
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.865281e-16
--    # #####  Iteration converged  #####
--
-- flux_top (	25	)=	-0.72291523102227
-- flux_bot (	25	)=	2.4713227150495e-13
-- mass_bot (	25	)=	3.0891533938119e-12
-- tlag=12.5
-- ++++++ TIMESTEP 1 END   (current time: 25) ++++++
-- ++++++ TIMESTEP 2 BEGIN (current time: 25) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    8.812092e-01      -------
--    #    1:    1.528293e-12    1.734313e-12
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.734313e-12
--    # #####  Iteration converged  #####
--
-- flux_top (	50	)=	-0.3232549148301
-- flux_bot (	50	)=	3.2496892731141e-12
-- mass_bot (	50	)=	4.679942270155e-11
-- tlag=35.598800756509
-- ++++++ TIMESTEP 2 END   (current time: 50) ++++++
-- ++++++ TIMESTEP 3 BEGIN (current time: 50) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.194549e-01      -------
--    #    1:    1.560209e-12    4.883974e-12
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.883974e-12
--    # #####  Iteration converged  #####
--
-- flux_top (	75	)=	-0.24754822010749
-- flux_bot (	75	)=	2.2511402530585e-11
-- mass_bot (	75	)=	3.6881307024779e-10
-- tlag=58.616610748855
-- ++++++ TIMESTEP 3 END   (current time: 75) ++++++
-- ++++++ TIMESTEP 4 BEGIN (current time: 75) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.079972e-01      -------
--    #    1:    1.641671e-12    7.892756e-12
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 7.892756e-12
--    # #####  Iteration converged  #####
--
-- flux_top (	100	)=	-0.20736584636641
-- flux_bot (	100	)=	1.0932510807526e-10
-- mass_bot (	100	)=	2.0167694528208e-09
-- tlag=81.552550111064
-- ++++++ TIMESTEP 4 END   (current time: 100) ++++++
-- ++++++ TIMESTEP 5 BEGIN (current time: 100) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.588466e-01      -------
--    #    1:    1.720278e-12    1.082980e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.082980e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	125	)=	-0.18191029180669
-- flux_bot (	125	)=	4.1796746045687e-10
-- mass_bot (	125	)=	8.6079265594724e-09
-- tlag=104.40527104655
-- ++++++ TIMESTEP 5 END   (current time: 125) ++++++
-- ++++++ TIMESTEP 6 BEGIN (current time: 125) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.307489e-01      -------
--    #    1:    1.635190e-12    1.250634e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.250634e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	150	)=	-0.16401563201433
-- flux_bot (	150	)=	1.3394561205686e-09
-- mass_bot (	150	)=	3.0575721322291e-08
-- tlag=127.17303250717
-- ++++++ TIMESTEP 6 END   (current time: 150) ++++++
-- ++++++ TIMESTEP 7 BEGIN (current time: 150) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.121943e-01      -------
--    #    1:    1.755239e-12    1.564464e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.564464e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	175	)=	-0.15056409605811
-- flux_bot (	175	)=	3.7417468084783e-09
-- mass_bot (	175	)=	9.4090757935377e-08
-- tlag=149.85378814991
-- ++++++ TIMESTEP 7 END   (current time: 175) ++++++
-- ++++++ TIMESTEP 8 BEGIN (current time: 175) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    9.885328e-02      -------
--    #    1:    1.749768e-12    1.770066e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.770066e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	200	)=	-0.1399737725132
-- flux_bot (	200	)=	9.3567044161412e-09
-- mass_bot (	200	)=	2.5782139824312e-07
-- tlag=172.44527701459
-- ++++++ TIMESTEP 8 END   (current time: 200) ++++++
-- ++++++ TIMESTEP 9 BEGIN (current time: 200) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    8.871673e-02      -------
--    #    1:    1.759997e-12    1.983839e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.983839e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	225	)=	-0.13135104585959
-- flux_bot (	225	)=	2.134904799297e-08
-- mass_bot (	225	)=	6.4164330335701e-07
-- tlag=194.94510932908
-- ++++++ TIMESTEP 9 END   (current time: 225) ++++++
-- ++++++ TIMESTEP 10 BEGIN (current time: 225) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    8.071167e-02      -------
--    #    1:    1.860181e-12    2.304724e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 2.304724e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	250	)=	-0.12414979390471
-- flux_bot (	250	)=	4.5089052144708e-08
-- mass_bot (	250	)=	1.472119555078e-06
-- tlag=217.35084272002
-- ++++++ TIMESTEP 10 END   (current time: 250) ++++++
-- ++++++ TIMESTEP 11 BEGIN (current time: 250) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    7.420639e-02      -------
--    #    1:    1.959506e-12    2.640616e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 2.640616e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	275	)=	-0.11801555221359
-- flux_bot (	275	)=	8.9130334984114e-08
-- mass_bot (	275	)=	3.1498618941883e-06
-- tlag=239.6600464954
-- ++++++ TIMESTEP 11 END   (current time: 275) ++++++
-- ++++++ TIMESTEP 12 BEGIN (current time: 275) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    6.880154e-02      -------
--    #    1:    1.876207e-12    2.726984e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 2.726984e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	300	)=	-0.11270701460635
-- flux_bot (	300	)=	1.6636948424354e-07
-- mass_bot (	300	)=	6.3436096345339e-06
-- tlag=261.87035342823
-- ++++++ TIMESTEP 12 END   (current time: 300) ++++++
-- ++++++ TIMESTEP 13 BEGIN (current time: 300) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    6.423062e-02      -------
--    #    1:    1.898033e-12    2.955028e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 2.955028e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	325	)=	-0.10805341694617
-- flux_bot (	325	)=	2.9533942525941e-07
-- mass_bot (	325	)=	1.2114971003321e-05
-- tlag=283.97949962935
-- ++++++ TIMESTEP 13 END   (current time: 325) ++++++
-- ++++++ TIMESTEP 14 BEGIN (current time: 325) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    6.030821e-02      -------
--    #    1:    1.840752e-12    3.052241e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 3.052241e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	350	)=	-0.1039299793697
-- flux_bot (	350	)=	5.0156722996923e-07
-- mass_bot (	350	)=	2.2076304193679e-05
-- tlag=305.98535375799
-- ++++++ TIMESTEP 14 END   (current time: 350) ++++++
-- ++++++ TIMESTEP 15 BEGIN (current time: 350) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.690091e-02      -------
--    #    1:    1.981572e-12    3.482496e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 3.482496e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	375	)=	-0.10024304368219
-- flux_bot (	375	)=	8.1891266738131e-07
-- mass_bot (	375	)=	3.8582302910561e-05
-- tlag=327.88593711227
-- ++++++ TIMESTEP 15 END   (current time: 375) ++++++
-- ++++++ TIMESTEP 16 BEGIN (current time: 375) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.391008e-02      -------
--    #    1:    1.958468e-12    3.632842e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 3.632842e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	400	)=	-0.096920698376551
-- flux_bot (	400	)=	1.29079808275e-06
-- mass_bot (	400	)=	6.4953687287202e-05
-- tlag=349.67943619127
-- ++++++ TIMESTEP 16 END   (current time: 400) ++++++
-- ++++++ TIMESTEP 17 BEGIN (current time: 400) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.126114e-02      -------
--    #    1:    1.735812e-12    3.386215e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 3.386215e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	425	)=	-0.093906650788537
-- flux_bot (	425	)=	1.9712435762637e-06
-- mass_bot (	425	)=	0.00010572920802487
-- tlag=371.36420922407
-- ++++++ TIMESTEP 17 END   (current time: 425) ++++++
-- ++++++ TIMESTEP 18 BEGIN (current time: 425) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.889656e-02      -------
--    #    1:    1.947541e-12    3.982981e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 3.982981e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	450	)=	-0.091156095515249
-- flux_bot (	450	)=	2.9256330079297e-06
-- mass_bot (	450	)=	0.00016694016532729
-- tlag=392.93878799056
-- ++++++ TIMESTEP 18 END   (current time: 450) ++++++
-- ++++++ TIMESTEP 19 BEGIN (current time: 450) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.677125e-02      -------
--    #    1:    2.063522e-12    4.411946e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.411946e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	475	)=	-0.088632851895857
-- flux_bot (	475	)=	4.2311541753197e-06
-- mass_bot (	475	)=	0.00025640000511791
-- tlag=414.40187606174
-- ++++++ TIMESTEP 19 END   (current time: 475) ++++++
-- ++++++ TIMESTEP 20 BEGIN (current time: 475) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.484930e-02      -------
--    #    1:    2.024604e-12    4.514237e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.514237e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	500	)=	-0.086307332576626
-- flux_bot (	500	)=	5.9768781536262e-06
-- mass_bot (	500	)=	0.00038400040922973
-- tlag=435.75234439123
-- ++++++ TIMESTEP 20 END   (current time: 500) ++++++
-- ++++++ TIMESTEP 21 BEGIN (current time: 500) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.310176e-02      -------
--    #    1:    2.084407e-12    4.836013e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.836013e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	525	)=	-0.084155070958392
-- flux_bot (	525	)=	8.2634657189016e-06
-- mass_bot (	525	)=	0.00056200470763633
-- tlag=456.98922501115
-- ++++++ TIMESTEP 21 END   (current time: 525) ++++++
-- ++++++ TIMESTEP 22 BEGIN (current time: 525) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.150503e-02      -------
--    #    1:    2.031825e-12    4.895369e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.895369e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	550	)=	-0.082155633508888
-- flux_bot (	550	)=	1.1202510722599e-05
-- mass_bot (	550	)=	0.00080532941315509
-- tlag=478.11170342998
-- ++++++ TIMESTEP 22 END   (current time: 550) ++++++
-- ++++++ TIMESTEP 23 BEGIN (current time: 550) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.003965e-02      -------
--    #    1:    1.950714e-12    4.871956e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.871956e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	575	)=	-0.08029180281392
-- flux_bot (	575	)=	1.4915549468799e-05
-- mass_bot (	575	)=	0.0011318051655476
-- tlag=499.11911020006
-- ++++++ TIMESTEP 23 END   (current time: 575) ++++++
-- ++++++ TIMESTEP 24 BEGIN (current time: 575) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.868941e-02      -------
--    #    1:    1.963740e-12    5.075653e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.075653e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	600	)=	-0.07854895476432
-- flux_bot (	600	)=	1.9532780383712e-05
-- mass_bot (	600	)=	0.001562409288704
-- tlag=520.01091201502
-- ++++++ TIMESTEP 24 END   (current time: 600) ++++++
-- ++++++ TIMESTEP 25 BEGIN (current time: 600) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.744074e-02      -------
--    #    1:    2.044504e-12    5.460641e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.460641e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	625	)=	-0.076914577366989
-- flux_bot (	625	)=	2.5191548977588e-05
-- mass_bot (	625	)=	0.0021214634057202
-- tlag=540.78670261175
-- ++++++ TIMESTEP 25 END   (current time: 625) ++++++
-- ++++++ TIMESTEP 26 BEGIN (current time: 625) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.628211e-02      -------
--    #    1:    2.040155e-12    5.623032e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.623032e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	650	)=	-0.075377894486423
-- flux_bot (	650	)=	3.2034659222339e-05
-- mass_bot (	650	)=	0.0028367910082193
-- tlag=561.44619368259
-- ++++++ TIMESTEP 26 END   (current time: 650) ++++++
-- ++++++ TIMESTEP 27 BEGIN (current time: 650) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.520376e-02      -------
--    #    1:    1.953665e-12    5.549593e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.549593e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	675	)=	-0.07392956842496
-- flux_bot (	675	)=	4.0208574349322e-05
-- mass_bot (	675	)=	0.0037398314278651
-- tlag=581.9892059496
-- ++++++ TIMESTEP 27 END   (current time: 675) ++++++
-- ++++++ TIMESTEP 28 BEGIN (current time: 675) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.419726e-02      -------
--    #    1:    2.057091e-12    6.015367e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.015367e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	700	)=	-0.07256146249379
-- flux_bot (	700	)=	4.9861568329387e-05
-- mass_bot (	700	)=	0.004865708211349
-- tlag=602.4156605102
-- ++++++ TIMESTEP 28 END   (current time: 700) ++++++
-- ++++++ TIMESTEP 29 BEGIN (current time: 700) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.325538e-02      -------
--    #    1:    2.091467e-12    6.289110e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.289110e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	725	)=	-0.071266449759715
-- flux_bot (	725	)=	6.1141884698141e-05
-- mass_bot (	725	)=	0.0062532513741931
-- tlag=622.72557053049
-- ++++++ TIMESTEP 29 END   (current time: 725) ++++++
-- ++++++ TIMESTEP 30 BEGIN (current time: 725) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.237182e-02      -------
--    #    1:    2.180938e-12    6.737151e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.737151e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	750	)=	-0.070038257710165
-- flux_bot (	750	)=	7.4195952743128e-05
-- mass_bot (	750	)=	0.0079449743422089
-- tlag=642.9190333371
-- ++++++ TIMESTEP 30 END   (current time: 750) ++++++
-- ++++++ TIMESTEP 31 BEGIN (current time: 750) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.154110e-02      -------
--    #    1:    2.217522e-12    7.030578e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 7.030578e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	775	)=	-0.068871341125526
-- flux_bot (	775	)=	8.9166703149608e-05
-- mass_bot (	775	)=	0.0099870075408681
-- tlag=662.99622293861
-- ++++++ TIMESTEP 31 END   (current time: 775) ++++++
-- ++++++ TIMESTEP 32 BEGIN (current time: 775) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.075842e-02      -------
--    #    1:    2.046391e-12    6.653110e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.653110e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	800	)=	-0.067760777301168
-- flux_bot (	800	)=	0.0001061920166916
-- mass_bot (	800	)=	0.012428991538883
-- tlag=682.95738299256
-- ++++++ TIMESTEP 32 END   (current time: 800) ++++++
-- ++++++ TIMESTEP 33 BEGIN (current time: 800) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    3.001953e-02      -------
--    #    1:    1.975337e-12    6.580173e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.580173e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	825	)=	-0.066702179122106
-- flux_bot (	825	)=	0.00012540333101967
-- mass_bot (	825	)=	0.015323933385274
-- tlag=702.80282022277
-- ++++++ TIMESTEP 33 END   (current time: 825) ++++++
-- ++++++ TIMESTEP 34 BEGIN (current time: 825) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.932069e-02      -------
--    #    1:    1.935548e-12    6.601306e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.601306e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	850	)=	-0.065691622506347
-- flux_bot (	850	)=	0.00014692442247163
-- mass_bot (	850	)=	0.018728030303916
-- tlag=722.53289828291
-- ++++++ TIMESTEP 34 END   (current time: 850) ++++++
-- ++++++ TIMESTEP 35 BEGIN (current time: 850) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.865858e-02      -------
--    #    1:    2.128706e-12    7.427813e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 7.427813e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	875	)=	-0.0647255854952
-- flux_bot (	875	)=	0.0001708703724264
-- mass_bot (	875	)=	0.022700465240141
-- tlag=742.14803205618
-- ++++++ TIMESTEP 35 END   (current time: 875) ++++++
-- ++++++ TIMESTEP 36 BEGIN (current time: 875) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.803023e-02      -------
--    #    1:    2.197704e-12    7.840476e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 7.840476e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	900	)=	-0.063800896845537
-- flux_bot (	900	)=	0.00019734672122963
-- mass_bot (	900	)=	0.027303178910841
-- tlag=761.64868237627
-- ++++++ TIMESTEP 36 END   (current time: 900) ++++++
-- ++++++ TIMESTEP 37 BEGIN (current time: 900) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.743300e-02      -------
--    #    1:    2.073572e-12    7.558676e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 7.558676e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	925	)=	-0.06291469242341
-- flux_bot (	925	)=	0.00022644880724237
-- mass_bot (	925	)=	0.032600623016741
-- tlag=781.0353511518
-- ++++++ TIMESTEP 37 END   (current time: 925) ++++++
-- ++++++ TIMESTEP 38 BEGIN (current time: 925) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.686450e-02      -------
--    #    1:    1.979496e-12    7.368445e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 7.368445e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	950	)=	-0.062064378037924
-- flux_bot (	950	)=	0.00025826128412379
-- mass_bot (	950	)=	0.038659499158818
-- tlag=800.30857687408
-- ++++++ TIMESTEP 38 END   (current time: 950) ++++++
-- ++++++ TIMESTEP 39 BEGIN (current time: 950) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.632259e-02      -------
--    #    1:    2.019275e-12    7.671261e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 7.671261e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	975	)=	-0.061247597623073
-- flux_bot (	975	)=	0.00029285780602101
-- mass_bot (	975	)=	0.045548487785628
-- tlag=819.46893048717
-- ++++++ TIMESTEP 39 END   (current time: 975) ++++++
-- ++++++ TIMESTEP 40 BEGIN (current time: 975) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.580533e-02      -------
--    #    1:    2.339094e-12    9.064382e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.064382e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1000	)=	-0.060462205881525
-- flux_bot (	1000	)=	0.00033030086782943
-- mass_bot (	1000	)=	0.053337971208759
-- tlag=838.51701159834
-- ++++++ TIMESTEP 40 END   (current time: 1000) ++++++
-- ++++++ TIMESTEP 41 BEGIN (current time: 1000) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.531098e-02      -------
--    #    1:    2.121908e-12    8.383351e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 8.383351e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1025	)=	-0.059706244670321
-- flux_bot (	1025	)=	0.00037064178600581
-- mass_bot (	1025	)=	0.062099754381699
-- tlag=857.45344500707
-- ++++++ TIMESTEP 41 END   (current time: 1025) ++++++
-- ++++++ TIMESTEP 42 BEGIN (current time: 1025) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.483793e-02      -------
--    #    1:    2.286367e-12    9.205143e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.205143e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1050	)=	-0.058977922539179
-- flux_bot (	1050	)=	0.00041392080445072
-- mass_bot (	1050	)=	0.071906786762406
-- tlag=876.27887753111
-- ++++++ TIMESTEP 42 END   (current time: 1050) ++++++
-- ++++++ TIMESTEP 43 BEGIN (current time: 1050) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.438473e-02      -------
--    #    1:    2.228553e-12    9.139133e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.139133e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1075	)=	-0.058275596935281
-- flux_bot (	1075	)=	0.00046016730961129
-- mass_bot (	1075	)=	0.082832888188181
-- tlag=894.99397510842
-- ++++++ TIMESTEP 43 END   (current time: 1075) ++++++
-- ++++++ TIMESTEP 44 BEGIN (current time: 1075) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.395007e-02      -------
--    #    1:    2.235962e-12    9.335933e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.335933e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1100	)=	-0.057597758675161
-- flux_bot (	1100	)=	0.00050940013907532
-- mass_bot (	1100	)=	0.094952481296764
-- tlag=913.599420155
-- ++++++ TIMESTEP 44 END   (current time: 1100) ++++++
-- ++++++ TIMESTEP 45 BEGIN (current time: 1100) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.353272e-02      -------
--    #    1:    2.106874e-12    8.952955e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 8.952955e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1125	)=	-0.056943018349407
-- flux_bot (	1125	)=	0.00056162796842839
-- mass_bot (	1125	)=	0.10834033264056
-- tlag=932.09590915899
-- ++++++ TIMESTEP 45 END   (current time: 1125) ++++++
-- ++++++ TIMESTEP 46 BEGIN (current time: 1125) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.313158e-02      -------
--    #    1:    2.139353e-12    9.248624e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.248624e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1150	)=	-0.05631009438215
-- flux_bot (	1150	)=	0.00061684976193205
-- mass_bot (	1150	)=	0.12307130427007
-- tlag=950.484150493
-- ++++++ TIMESTEP 46 END   (current time: 1150) ++++++
-- ++++++ TIMESTEP 47 BEGIN (current time: 1150) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.274563e-02      -------
--    #    1:    2.223396e-12    9.775047e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.775047e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1175	)=	-0.055697802513795
-- flux_bot (	1175	)=	0.00067505527356892
-- mass_bot (	1175	)=	0.13922011721383
-- tlag=968.76486242706
-- ++++++ TIMESTEP 47 END   (current time: 1175) ++++++
-- ++++++ TIMESTEP 48 BEGIN (current time: 1175) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.237392e-02      -------
--    #    1:    2.090387e-12    9.342964e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.342964e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1200	)=	-0.055105046510072
-- flux_bot (	1200	)=	0.00073622558612091
-- mass_bot (	1200	)=	0.15686112795995
-- tlag=986.93877132628
-- ++++++ TIMESTEP 48 END   (current time: 1200) ++++++
-- ++++++ TIMESTEP 49 BEGIN (current time: 1200) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.201558e-02      -------
--    #    1:    2.159993e-12    9.811203e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.811203e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1225	)=	-0.05453080993175
-- flux_bot (	1225	)=	0.00080033367713886
-- mass_bot (	1225	)=	0.1760681187507
-- tlag=1005.0066100178
-- ++++++ TIMESTEP 49 END   (current time: 1225) ++++++
-- ++++++ TIMESTEP 50 BEGIN (current time: 1225) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.166982e-02      -------
--    #    1:    2.122845e-12    9.796321e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.796321e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1250	)=	-0.053974148826045
-- flux_bot (	1250	)=	0.00086734500188062
-- mass_bot (	1250	)=	0.19691410223844
-- tlag=1022.969116313
-- ++++++ TIMESTEP 50 END   (current time: 1250) ++++++
-- ++++++ TIMESTEP 51 BEGIN (current time: 1250) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.133589e-02      -------
--    #    1:    2.198116e-12    1.030244e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.030244e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1275	)=	-0.053434185219346
-- flux_bot (	1275	)=	0.00093721808450068
-- mass_bot (	1275	)=	0.21947114081821
-- tlag=1040.827031672
-- ++++++ TIMESTEP 51 END   (current time: 1275) ++++++
-- ++++++ TIMESTEP 52 BEGIN (current time: 1275) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.101310e-02      -------
--    #    1:    2.240442e-12    1.066212e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.066212e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1300	)=	-0.05291010130973
-- flux_bot (	1300	)=	0.0010099051099419
-- mass_bot (	1300	)=	0.24381018074874
-- tlag=1058.5810999978
-- ++++++ TIMESTEP 52 END   (current time: 1300) ++++++
-- ++++++ TIMESTEP 53 BEGIN (current time: 1300) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.070081e-02      -------
--    #    1:    2.068818e-12    9.993899e-11
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 9.993899e-11
--    # #####  Iteration converged  #####
--
-- flux_top (	1325	)=	-0.052401134272292
-- flux_bot (	1325	)=	0.0010853525100864
-- mass_bot (	1325	)=	0.27000090099909
-- tlag=1076.2320665499
-- ++++++ TIMESTEP 53 END   (current time: 1325) ++++++
-- ++++++ TIMESTEP 54 BEGIN (current time: 1325) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.039844e-02      -------
--    #    1:    2.247505e-12    1.101803e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.101803e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1350	)=	-0.051906571602388
-- flux_bot (	1350	)=	0.0011635015387553
-- mass_bot (	1350	)=	0.29811157660961
-- tlag=1093.7806769654
-- ++++++ TIMESTEP 54 END   (current time: 1350) ++++++
-- ++++++ TIMESTEP 55 BEGIN (current time: 1350) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    2.010542e-02      -------
--    #    1:    2.230451e-12    1.109378e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.109378e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1375	)=	-0.051425746931716
-- flux_bot (	1375	)=	0.0012442888310974
-- mass_bot (	1375	)=	0.32820895623277
-- tlag=1111.2276763802
-- ++++++ TIMESTEP 55 END   (current time: 1375) ++++++
-- ++++++ TIMESTEP 56 BEGIN (current time: 1375) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.982125e-02      -------
--    #    1:    2.135838e-12    1.077550e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.077550e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1400	)=	-0.050958036262613
-- flux_bot (	1400	)=	0.001327646943768
-- mass_bot (	1400	)=	0.36035815341859
-- tlag=1128.5738086393
-- ++++++ TIMESTEP 56 END   (current time: 1400) ++++++
-- ++++++ TIMESTEP 57 BEGIN (current time: 1400) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.954544e-02      -------
--    #    1:    2.451858e-12    1.254440e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.254440e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1425	)=	-0.050502854570624
-- flux_bot (	1425	)=	0.001413504873076
-- mass_bot (	1425	)=	0.39462255112914
-- tlag=1145.8198155905
-- ++++++ TIMESTEP 57 END   (current time: 1425) ++++++
-- ++++++ TIMESTEP 58 BEGIN (current time: 1425) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.927755e-02      -------
--    #    1:    2.224120e-12    1.153736e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.153736e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1450	)=	-0.050059652734984
-- flux_bot (	1450	)=	0.0015017885489604
-- mass_bot (	1450	)=	0.4310637189046
-- tlag=1162.9664364514
-- ++++++ TIMESTEP 58 END   (current time: 1450) ++++++
-- ++++++ TIMESTEP 59 BEGIN (current time: 1450) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.901716e-02      -------
--    #    1:    2.228782e-12    1.171985e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.171985e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1475	)=	-0.049627914759471
-- flux_bot (	1475	)=	0.0015924213032656
-- mass_bot (	1475	)=	0.46974134205742
-- tlag=1180.0144072463
-- ++++++ TIMESTEP 59 END   (current time: 1475) ++++++
-- ++++++ TIMESTEP 60 BEGIN (current time: 1475) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.876388e-02      -------
--    #    1:    2.242926e-12    1.195342e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.195342e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1500	)=	-0.049207155251721
-- flux_bot (	1500	)=	0.0016853243113043
-- mass_bot (	1500	)=	0.51071316223954
-- tlag=1196.9644603036
-- ++++++ TIMESTEP 60 END   (current time: 1500) ++++++
-- ++++++ TIMESTEP 61 BEGIN (current time: 1500) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.851735e-02      -------
--    #    1:    2.355148e-12    1.271860e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.271860e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1525	)=	-0.048796917133759
-- flux_bot (	1525	)=	0.0017804170061519
-- mass_bot (	1525	)=	0.55403492870775
-- tlag=1213.8173238104
-- ++++++ TIMESTEP 61 END   (current time: 1525) ++++++
-- ++++++ TIMESTEP 62 BEGIN (current time: 1525) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.827721e-02      -------
--    #    1:    2.180388e-12    1.192954e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.192954e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1550	)=	-0.048396769558046
-- flux_bot (	1550	)=	0.0018776174654947
-- mass_bot (	1550	)=	0.59976035960333
-- tlag=1230.5737214181
-- ++++++ TIMESTEP 62 END   (current time: 1550) ++++++
-- ++++++ TIMESTEP 63 BEGIN (current time: 1550) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.804316e-02      -------
--    #    1:    2.318831e-12    1.285157e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.285157e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1575	)=	-0.048006306008941
-- flux_bot (	1575	)=	0.0019768427711784
-- mass_bot (	1575	)=	0.64794111256174
-- tlag=1247.2343718942
-- ++++++ TIMESTEP 63 END   (current time: 1575) ++++++
-- ++++++ TIMESTEP 64 BEGIN (current time: 1575) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.781490e-02      -------
--    #    1:    2.253698e-12    1.265064e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.265064e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1600	)=	-0.047625142568864
-- flux_bot (	1600	)=	0.0020780093418682
-- mass_bot (	1600	)=	0.69862676397482
-- tlag=1263.7999888168
-- ++++++ TIMESTEP 64 END   (current time: 1600) ++++++
-- ++++++ TIMESTEP 65 BEGIN (current time: 1600) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.759213e-02      -------
--    #    1:    2.219176e-12    1.261460e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.261460e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1625	)=	-0.047252916334185
-- flux_bot (	1625	)=	0.0021810332394467
-- mass_bot (	1625	)=	0.75186479624126
-- tlag=1280.2712803075
-- ++++++ TIMESTEP 65 END   (current time: 1625) ++++++
-- ++++++ TIMESTEP 66 BEGIN (current time: 1625) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.737460e-02      -------
--    #    1:    2.323719e-12    1.337423e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.337423e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1650	)=	-0.046889283964223
-- flux_bot (	1650	)=	0.0022858304499499
-- mass_bot (	1650	)=	0.80770059235872
-- tlag=1296.6489487983
-- ++++++ TIMESTEP 66 END   (current time: 1650) ++++++
-- ++++++ TIMESTEP 67 BEGIN (current time: 1650) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.716206e-02      -------
--    #    1:    2.319767e-12    1.351683e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.351683e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1675	)=	-0.046533920351748
-- flux_bot (	1675	)=	0.0023923171399756
-- mass_bot (	1675	)=	0.86617743723279
-- tlag=1312.933690831
-- ++++++ TIMESTEP 67 END   (current time: 1675) ++++++
-- ++++++ TIMESTEP 68 BEGIN (current time: 1675) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.695428e-02      -------
--    #    1:    2.217471e-12    1.307912e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.307912e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1700	)=	-0.046186517401892
-- flux_bot (	1700	)=	0.0025004098895974
-- mass_bot (	1700	)=	0.92733652510245
-- tlag=1329.1261968846
-- ++++++ TIMESTEP 68 END   (current time: 1700) ++++++
-- ++++++ TIMESTEP 69 BEGIN (current time: 1700) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.675104e-02      -------
--    #    1:    2.342438e-12    1.398383e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.398383e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1725	)=	-0.045846782910228
-- flux_bot (	1725	)=	0.0026100259028932
-- mass_bot (	1725	)=	0.99121697250858
-- tlag=1345.2271512287
-- ++++++ TIMESTEP 69 END   (current time: 1725) ++++++
-- ++++++ TIMESTEP 70 BEGIN (current time: 1725) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.655214e-02      -------
--    #    1:    2.241290e-12    1.354079e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.354079e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1750	)=	-0.045514439529998
-- flux_bot (	1750	)=	0.0027210831972412
-- mass_bot (	1750	)=	1.0578558362603
-- tlag=1361.2372318006
-- ++++++ TIMESTEP 70 END   (current time: 1750) ++++++
-- ++++++ TIMESTEP 71 BEGIN (current time: 1750) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.635738e-02      -------
--    #    1:    2.257011e-12    1.379813e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.379813e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1775	)=	-0.045189223820406
-- flux_bot (	1775	)=	0.0028335007725666
-- mass_bot (	1775	)=	1.1272881358829
-- tlag=1377.1571101031
-- ++++++ TIMESTEP 71 END   (current time: 1775) ++++++
-- ++++++ TIMESTEP 72 BEGIN (current time: 1775) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.616658e-02      -------
--    #    1:    2.404854e-12    1.487547e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.487547e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	1800	)=	-0.044870885368531
-- flux_bot (	1800	)=	0.0029471987617289
-- mass_bot (	1800	)=	1.1995468800616
-- tlag=1392.9874511219
-- ++++++ TIMESTEP 72 END   (current time: 1800) ++++++
-- ++++++ TIMESTEP 73 BEGIN (current time: 1800) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    1.597957e-02      -------
--    #    1:    2.205523e-12    1.380215e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 1.380215e-10
-- ...
--    # #####  Iteration converged  #####
--
-- flux_top (	4400	)=	-0.028824750842637
-- flux_bot (	4400	)=	0.013929449009747
-- mass_bot (	4400	)=	24.395544744434
-- tlag=2648.6353388878
-- ++++++ TIMESTEP 176 END   (current time: 4400) ++++++
-- ++++++ TIMESTEP 177 BEGIN (current time: 4400) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.536131e-03      -------
--    #    1:    2.548636e-12    4.603641e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.603641e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4425	)=	-0.028749605894128
-- flux_bot (	4425	)=	0.014001149810424
-- mass_bot (	4425	)=	24.744677229686
-- tlag=2657.6682047739
-- ++++++ TIMESTEP 177 END   (current time: 4425) ++++++
-- ++++++ TIMESTEP 178 BEGIN (current time: 4425) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.481531e-03      -------
--    #    1:    2.570967e-12    4.690235e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.690235e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4450	)=	-0.028675250531299
-- flux_bot (	4450	)=	0.014072192373965
-- mass_bot (	4450	)=	25.095594006991
-- tlag=2666.6535718045
-- ++++++ TIMESTEP 178 END   (current time: 4450) ++++++
-- ++++++ TIMESTEP 179 BEGIN (current time: 4450) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.427471e-03      -------
--    #    1:    2.690552e-12    4.957284e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.957284e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4475	)=	-0.028601675106349
-- flux_bot (	4475	)=	0.014142581338834
-- mass_bot (	4475	)=	25.448278678401
-- tlag=2675.5916693212
-- ++++++ TIMESTEP 179 END   (current time: 4475) ++++++
-- ++++++ TIMESTEP 180 BEGIN (current time: 4475) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.373945e-03      -------
--    #    1:    2.671190e-12    4.970632e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.970632e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4500	)=	-0.028528870138252
-- flux_bot (	4500	)=	0.014212321368069
-- mass_bot (	4500	)=	25.802714962237
-- tlag=2684.4827249538
-- ++++++ TIMESTEP 180 END   (current time: 4500) ++++++
-- ++++++ TIMESTEP 181 BEGIN (current time: 4500) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.320948e-03      -------
--    #    1:    2.590348e-12    4.868208e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.868208e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4525	)=	-0.028456826307668
-- flux_bot (	4525	)=	0.014281417146378
-- mass_bot (	4525	)=	26.158886693668
-- tlag=2693.3269646457
-- ++++++ TIMESTEP 181 END   (current time: 4525) ++++++
-- ++++++ TIMESTEP 182 BEGIN (current time: 4525) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.268475e-03      -------
--    #    1:    2.799048e-12    5.312824e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.312824e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4550	)=	-0.028385534453394
-- flux_bot (	4550	)=	0.014349873377371
-- mass_bot (	4550	)=	26.516777825215
-- tlag=2702.1246126791
-- ++++++ TIMESTEP 182 END   (current time: 4550) ++++++
-- ++++++ TIMESTEP 183 BEGIN (current time: 4550) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.216520e-03      -------
--    #    1:    2.597866e-12    4.980075e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.980075e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4575	)=	-0.028314985567886
-- flux_bot (	4575	)=	0.014417694780906
-- mass_bot (	4575	)=	26.876372427193
-- tlag=2710.8758917003
-- ++++++ TIMESTEP 183 END   (current time: 4575) ++++++
-- ++++++ TIMESTEP 184 BEGIN (current time: 4575) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.165078e-03      -------
--    #    1:    2.635254e-12    5.102060e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.102060e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4600	)=	-0.028245170793288
-- flux_bot (	4600	)=	0.014484886090563
-- mass_bot (	4600	)=	27.237654688086
-- tlag=2719.581022744
-- ++++++ TIMESTEP 184 END   (current time: 4600) ++++++
-- ++++++ TIMESTEP 185 BEGIN (current time: 4600) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.114145e-03      -------
--    #    1:    2.528273e-12    4.943687e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.943687e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4625	)=	-0.028176081417989
-- flux_bot (	4625	)=	0.014551452051224
-- mass_bot (	4625	)=	27.600608914859
-- tlag=2728.2402252573
-- ++++++ TIMESTEP 185 END   (current time: 4625) ++++++
-- ++++++ TIMESTEP 186 BEGIN (current time: 4625) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.063714e-03      -------
--    #    1:    2.490397e-12    4.918124e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 4.918124e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4650	)=	-0.02810770887233
-- flux_bot (	4650	)=	0.014617397416765
-- mass_bot (	4650	)=	27.965219533209
-- tlag=2736.8537171238
-- ++++++ TIMESTEP 186 END   (current time: 4650) ++++++
-- ++++++ TIMESTEP 187 BEGIN (current time: 4650) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    5.013782e-03      -------
--    #    1:    2.602896e-12    5.191483e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.191483e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4675	)=	-0.028040044725696
-- flux_bot (	4675	)=	0.014682726947859
-- mass_bot (	4675	)=	28.331471087766
-- tlag=2745.4217146872
-- ++++++ TIMESTEP 187 END   (current time: 4675) ++++++
-- ++++++ TIMESTEP 188 BEGIN (current time: 4675) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.964342e-03      -------
--    #    1:    2.607354e-12    5.252163e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.252163e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4700	)=	-0.027973080682479
-- flux_bot (	4700	)=	0.01474744540987
-- mass_bot (	4700	)=	28.699348242238
-- tlag=2753.944432774
-- ++++++ TIMESTEP 188 END   (current time: 4700) ++++++
-- ++++++ TIMESTEP 189 BEGIN (current time: 4700) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.915391e-03      -------
--    #    1:    2.565493e-12    5.219305e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.219305e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4725	)=	-0.02790680857924
-- flux_bot (	4725	)=	0.014811557570849
-- mass_bot (	4725	)=	29.068835779497
-- tlag=2762.4220847166
-- ++++++ TIMESTEP 189 END   (current time: 4725) ++++++
-- ++++++ TIMESTEP 190 BEGIN (current time: 4725) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.866923e-03      -------
--    #    1:    2.616651e-12    5.376397e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.376397e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4750	)=	-0.027841220381121
-- flux_bot (	4750	)=	0.01487506819963
-- mass_bot (	4750	)=	29.439918601628
-- tlag=2770.8548823756
-- ++++++ TIMESTEP 190 END   (current time: 4750) ++++++
-- ++++++ TIMESTEP 191 BEGIN (current time: 4750) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.818934e-03      -------
--    #    1:    2.563194e-12    5.319006e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.319006e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4775	)=	-0.027776308178799
-- flux_bot (	4775	)=	0.014937982064003
-- mass_bot (	4775	)=	29.812581729923
-- tlag=2779.2430361619
-- ++++++ TIMESTEP 191 END   (current time: 4775) ++++++
-- ++++++ TIMESTEP 192 BEGIN (current time: 4775) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.771418e-03      -------
--    #    1:    2.686741e-12    5.630907e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.630907e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4800	)=	-0.027712064185733
-- flux_bot (	4800	)=	0.015000303928985
-- mass_bot (	4800	)=	30.186810304836
-- tlag=2787.5867550586
-- ++++++ TIMESTEP 192 END   (current time: 4800) ++++++
-- ++++++ TIMESTEP 193 BEGIN (current time: 4800) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.724371e-03      -------
--    #    1:    2.509715e-12    5.312273e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.312273e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4825	)=	-0.027648480734831
-- flux_bot (	4825	)=	0.015062038555165
-- mass_bot (	4825	)=	30.562589585888
-- tlag=2795.8862466424
-- ++++++ TIMESTEP 193 END   (current time: 4825) ++++++
-- ++++++ TIMESTEP 194 BEGIN (current time: 4825) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.677789e-03      -------
--    #    1:    2.618482e-12    5.597693e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.597693e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4850	)=	-0.027585550276025
-- flux_bot (	4850	)=	0.015123190697134
-- mass_bot (	4850	)=	30.939904951541
-- tlag=2804.1417171044
-- ++++++ TIMESTEP 194 END   (current time: 4850) ++++++
-- ++++++ TIMESTEP 195 BEGIN (current time: 4850) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.631666e-03      -------
--    #    1:    2.766590e-12    5.973207e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.973207e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4875	)=	-0.027523265373178
-- flux_bot (	4875	)=	0.015183765101991
-- mass_bot (	4875	)=	31.31874189903
-- tlag=2812.3533712713
-- ++++++ TIMESTEP 195 END   (current time: 4875) ++++++
-- ++++++ TIMESTEP 196 BEGIN (current time: 4875) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.585999e-03      -------
--    #    1:    2.697304e-12    5.881606e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.881606e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4900	)=	-0.027461618701774
-- flux_bot (	4900	)=	0.015243766507921
-- mass_bot (	4900	)=	31.699086044154
-- tlag=2820.5214126258
-- ++++++ TIMESTEP 196 END   (current time: 4900) ++++++
-- ++++++ TIMESTEP 197 BEGIN (current time: 4900) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.540782e-03      -------
--    #    1:    2.611839e-12    5.751958e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.751958e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4925	)=	-0.027400603046137
-- flux_bot (	4925	)=	0.015303199642843
-- mass_bot (	4925	)=	32.080923121039
-- tlag=2828.6460433265
-- ++++++ TIMESTEP 197 END   (current time: 4925) ++++++
-- ++++++ TIMESTEP 198 BEGIN (current time: 4925) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.496011e-03      -------
--    #    1:    2.636135e-12    5.863275e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 5.863275e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4950	)=	-0.027340211296968
-- flux_bot (	4950	)=	0.015362069223126
-- mass_bot (	4950	)=	32.464238981863
-- tlag=2836.7274642278
-- ++++++ TIMESTEP 198 END   (current time: 4950) ++++++
-- ++++++ TIMESTEP 199 BEGIN (current time: 4950) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.451682e-03      -------
--    #    1:    2.712522e-12    6.093252e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.093252e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	4975	)=	-0.02728043644906
-- flux_bot (	4975	)=	0.015420379952373
-- mass_bot (	4975	)=	32.849019596557
-- tlag=2844.7658748998
-- ++++++ TIMESTEP 199 END   (current time: 4975) ++++++
-- ++++++ TIMESTEP 200 BEGIN (current time: 4975) ++++++
-- ++++++ Time step size: 25
--
--    # ########     Newton Solver     #######################
--    # ########  (Linear Solver: LU)  #######################
--    #   Iter      Defect         Rate
--    #    0:    4.407791e-03      -------
--    #    1:    2.716887e-12    6.163828e-10
--    # Relative reduction 1.000000e-06 reached after 1 steps.
--    # Average reduction over 1 steps: 6.163828e-10
--    # #####  Iteration converged  #####
--
-- flux_top (	5000	)=	-0.027221271598817
-- flux_bot (	5000	)=	0.015478136520264
-- mass_bot (	5000	)=	33.235251052465
-- tlag=2852.7614736469
-- ++++++ TIMESTEP 200 END   (current time: 5000) ++++++
