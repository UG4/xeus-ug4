# %% [markdown]
# # Visualization: Example using pyvista
#
# The following lines are only required on binder. We define a missing `DISPLAY` variable.

# %%
import os
os.environ['DISPLAY']=':99.0'

import subprocess
commands = ['Xvfb :99 -screen 0 1024x768x24 > /dev/null 2>&1 &',
            'sleep 3',
            'exec \"$@\"']
 
for command in commands:
    subprocess.call(command,shell=True)

# %% [markdown]
# Now we can use VTK through pyvista:

# %%
import pyvista
usingJupyterNotebook = True

# %% [markdown]
# ## Option 1: Direct plot

# %%
sol = pyvista.read('tutorial-fem/x_solution.vtu')
sol.plot(notebook=usingJupyterNotebook, interactive=True)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FEFEC035850>

# %% [markdown]
# ## Option 2: Fine-grained configuration using Plotter

# %%
plotter = pyvista.Plotter(2,2)
plotter.add_mesh(sol, scalars="u", clim=[0, 1], cmap="fire", lighting=True, stitle="Solution u")
plotter.show()
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768 at 0x7FEFEEE39C10>
